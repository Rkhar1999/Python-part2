# %% [markdown]
# # What is Statistics?
#
# **Statistics** is the branch of mathematics that deals with the collection, analysis, interpretation, presentation, and organization of data. It provides tools and methods to understand data, identify patterns, and make informed decisions. Statistics is widely used in various fields such as business, medicine, social sciences, and technology to analyze real-world phenomena.
#
# ### Types of Statistics:
# 1. **Descriptive Statistics**:
#    - Summarizes and describes the features of a dataset.
#    - Examples: Mean, Median, Mode, Standard Deviation, and Visualizations like charts or graphs.
#
# 2. **Inferential Statistics**:
#    - Uses data from a sample to make predictions or generalizations about a population.
#    - Examples: Hypothesis Testing, Confidence Intervals, Regression Analysis.
#
# ---
#
# ### Simple Example:
# Let’s say we have the scores of five students in a test: [78, 85, 90, 72, 88]. Using descriptive statistics, we can find measures like:
# - **Mean (average)**: A single value representing the central point of data.
# - **Median**: The middle value when the data is sorted.
# - **Mode**: The most frequently occurring value.
#
# ---
#
# ### Python Code Using Pandas:

# %%
import pandas as pd

# %%
import seaborn as sns

# %%
tips = sns.load_dataset("tips")

# %%
tips.describe()
# Out:
#        total_bill         tip        size
# count  244.000000  244.000000  244.000000
# mean    19.785943    2.998279    2.569672
# std      8.902412    1.383638    0.951100
# min      3.070000    1.000000    1.000000
# 25%     13.347500    2.000000    2.000000
# 50%     17.795000    2.900000    2.000000
# 75%     24.127500    3.562500    3.000000
# max     50.810000   10.000000    6.000000

# %%
import pandas as pd

# Create a dataset
data = {'Student': ['A', 'B', 'C', 'D', 'E'], 'Score': [78, 85, 90, 72, 88]}
df = pd.DataFrame(data)

# Descriptive Statistics
mean = df['Score'].mean()  # Mean
median = df['Score'].median()  # Median
mode = df['Score'].mode()[0]  # Mode
std_dev = df['Score'].std()  # Standard Deviation

# Display results
print("Dataset:")
print(df)
print("\nDescriptive Statistics:")
print(f"Mean: {mean}")
print(f"Median: {median}")
print(f"Mode: {mode}")
print(f"Standard Deviation: {std_dev}")
# Out:
# Dataset:
#   Student  Score
# 0       A     78
# 1       B     85
# 2       C     90
# 3       D     72
# 4       E     88
#
# Descriptive Statistics:
# Mean: 82.6
# Median: 85.0
# Mode: 72
# Standard Deviation: 7.46993975879324

# %%
import seaborn as sns

# %%
titanic_df = sns.load_dataset("titanic")

# %%
titanic_df
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 0           0       3    male  22.0      1      0   7.2500        S   Third
# 1           1       1  female  38.0      1      0  71.2833        C   First
# 2           1       3  female  26.0      0      0   7.9250        S   Third
# 3           1       1  female  35.0      1      0  53.1000        S   First
# 4           0       3    male  35.0      0      0   8.0500        S   Third
# ..        ...     ...     ...   ...    ...    ...      ...      ...     ...
# 886         0       2    male  27.0      0      0  13.0000        S  Second
# 887         1       1  female  19.0      0      0  30.0000        S   First
# 888         0       3  female   NaN      1      2  23.4500        S   Third
# 889         1       1    male  26.0      0      0  30.0000        C   First
# 890         0       3    male  32.0      0      0   7.7500        Q   Third
#
#        who  adult_male deck  embark_town alive  alone
# ...

# %% [markdown]
# ### **Population and Sample**
#
# #### **1. What is Population?**
# A **population** in statistics refers to the entire group that you are interested in studying or analyzing. It includes all individuals or items that meet specific criteria. The population can be finite (e.g., all students in a school) or infinite (e.g., all the stars in the universe).
#
# **Example**:
# - The population of a country.
# - All employees in a company.
# - Every car produced by a manufacturer in a year.
#
# #### **2. What is a Sample?**
# A **sample** is a subset of the population that is selected for the purpose of analysis. It is often impossible or impractical to study an entire population, so a sample is used to make inferences about the population.
#
# **Key Properties**:
# - A sample should be representative of the population.
# - It is usually selected randomly to avoid bias.
#
# **Example**:
# - A survey of 100 students to understand the preferences of all students in a school.
# - Testing 1,000 cars from a production line to infer quality control for the entire batch.
#
# ---
#
# ### **Population vs Sample**
#
# | **Aspect**            | **Population**                               | **Sample**                                 |
# |------------------------|----------------------------------------------|--------------------------------------------|
# | **Definition**         | Entire group of interest                    | Subset of the population                   |
# | **Size**               | Usually large                               | Smaller and manageable                     |
# | **Analysis**           | Harder to study directly                    | Easier to study                            |
# | **Purpose**            | Provides complete insight                   | Used to make inferences about the population |
# | **Example**            | All students in a school                    | 50 randomly selected students              |
#
# ---
#
# ### **Simple Example in Context**
# Imagine you want to calculate the average height of all the students in a school of 1,000 students. Measuring all 1,000 heights (the **population**) would be time-consuming. Instead, you measure the height of 100 randomly selected students (the **sample**) and use it to estimate the average height for the entire school.
#
# ---

# %%
titanic_df
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 0           0       3    male  22.0      1      0   7.2500        S   Third
# 1           1       1  female  38.0      1      0  71.2833        C   First
# 2           1       3  female  26.0      0      0   7.9250        S   Third
# 3           1       1  female  35.0      1      0  53.1000        S   First
# 4           0       3    male  35.0      0      0   8.0500        S   Third
# ..        ...     ...     ...   ...    ...    ...      ...      ...     ...
# 886         0       2    male  27.0      0      0  13.0000        S  Second
# 887         1       1  female  19.0      0      0  30.0000        S   First
# 888         0       3  female   NaN      1      2  23.4500        S   Third
# 889         1       1    male  26.0      0      0  30.0000        C   First
# 890         0       3    male  32.0      0      0   7.7500        Q   Third
#
#        who  adult_male deck  embark_town alive  alone
# ...

# %%
titanic_df.head()
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 0         0       3    male  22.0      1      0   7.2500        S  Third
# 1         1       1  female  38.0      1      0  71.2833        C  First
# 2         1       3  female  26.0      0      0   7.9250        S  Third
# 3         1       1  female  35.0      1      0  53.1000        S  First
# 4         0       3    male  35.0      0      0   8.0500        S  Third
#
#      who  adult_male deck  embark_town alive  alone
# 0    man        True  NaN  Southampton    no  False
# 1  woman       False    C    Cherbourg   yes  False
# 2  woman       False  NaN  Southampton   yes   True
# 3  woman       False    C  Southampton   yes  False
# 4    man        True  NaN  Southampton    no   True

# %%
titanic_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 15 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   survived     891 non-null    int64
#  1   pclass       891 non-null    int64
#  2   sex          891 non-null    object
#  3   age          714 non-null    float64
#  4   sibsp        891 non-null    int64
#  5   parch        891 non-null    int64
#  6   fare         891 non-null    float64
#  7   embarked     889 non-null    object
#  8   class        891 non-null    category
#  9   who          891 non-null    object
#  10  adult_male   891 non-null    bool
#  11  deck         203 non-null    category
#  12  embark_town  889 non-null    object
#  13  alive        891 non-null    object
#  14  alone        891 non-null    bool
# dtypes: bool(2), category(2), float64(2), int64(4), object(5)
# memory usage: 80.7+ KB

# %%
titanic_df["age"].mean()
# Out:
# 29.69911764705882

# %%
### Code Implementation Using Pandas

import pandas as pd



# Step 1: Population statistics
population = titanic_df
population_mean_age = population['age'].mean()  # Mean age of the population
population_std_age = population['age'].std()  # Standard deviation of the population age

# %%
population
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 0           0       3    male  22.0      1      0   7.2500        S   Third
# 1           1       1  female  38.0      1      0  71.2833        C   First
# 2           1       3  female  26.0      0      0   7.9250        S   Third
# 3           1       1  female  35.0      1      0  53.1000        S   First
# 4           0       3    male  35.0      0      0   8.0500        S   Third
# ..        ...     ...     ...   ...    ...    ...      ...      ...     ...
# 886         0       2    male  27.0      0      0  13.0000        S  Second
# 887         1       1  female  19.0      0      0  30.0000        S   First
# 888         0       3  female   NaN      1      2  23.4500        S   Third
# 889         1       1    male  26.0      0      0  30.0000        C   First
# 890         0       3    male  32.0      0      0   7.7500        Q   Third
#
#        who  adult_male deck  embark_town alive  alone
# ...

# %%
sample_size
# Out:
# 178

# %%
# Step 2: Draw a random sample (e.g., 20% of the population)
sample_size = int(len(population) * 0.2)



sample = population.sample(n=sample_size, random_state=42)

# %%
sample
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 709         1       3    male   NaN      1      1  15.2458        C   Third
# 439         0       2    male  31.0      0      0  10.5000        S  Second
# 840         0       3    male  20.0      0      0   7.9250        S   Third
# 720         1       2  female   6.0      0      1  33.0000        S  Second
# 39          1       3  female  14.0      1      0  11.2417        C   Third
# ..        ...     ...     ...   ...    ...    ...      ...      ...     ...
# 852         0       3  female   9.0      1      1  15.2458        C   Third
# 433         0       3    male  17.0      0      0   7.1250        S   Third
# 773         0       3    male   NaN      0      0   7.2250        C   Third
# 25          1       3  female  38.0      1      5  31.3875        S   Third
# 84          1       2  female  17.0      0      0  10.5000        S  Second
#
#        who  adult_male deck  embark_town alive  alone
# ...

# %%
sample["age"].mean()
# Out:
# 30.69382978723404

# %%
sample_mean_age = sample['age'].mean()  # Mean age of the sample
sample_std_age = sample['age'].std()  # Standard deviation of the sample age

# %%
# Step 3: Display results
print("Population Statistics:")
print(f"Total Population Size: {len(population)}")
print(f"Mean Age: {population_mean_age:.2f}")
print(f"Standard Deviation of Age: {population_std_age:.2f}")
# Out:
# Population Statistics:
# Total Population Size: 891
# Mean Age: 29.70
# Standard Deviation of Age: 14.53

# %%
print("\nSample Statistics (20% of Population):")
print(f"Sample Size: {len(sample)}")
print(f"Mean Age: {sample_mean_age:.2f}")
print(f"Standard Deviation of Age: {sample_std_age:.2f}")
# Out:
# Sample Statistics (20% of Population):
# Sample Size: 178
# Mean Age: 30.69
# Standard Deviation of Age: 14.54

# %% [markdown]
# ---
#
# ### Explanation of the Code:
# 1. **Population Statistics**:
#    - The entire Titanic dataset is considered as the population.
#    - We calculate the **mean age** and **standard deviation** of the population using Pandas' `.mean()` and `.std()` methods.
#
# 2. **Sample Statistics**:
#    - A random sample is drawn from the population using the Pandas `.sample()` method.
#    - The sample size is set to 20% of the population.
#    - Mean and standard deviation are calculated for the sample.
#
# 3. **Pandas Methods Used**:
#    - `.mean()`: Computes the mean of a column.
#    - `.std()`: Computes the standard deviation of a column.
#    - `.sample()`: Randomly selects rows from the dataset.
#
# ---
#
# ### Example Output:
# ```
# Population Statistics:
# Total Population Size: 891
# Mean Age: 29.70
# Standard Deviation of Age: 14.52
#
# Sample Statistics (20% of Population):
# Sample Size: 178
# Mean Age: 30.17
# Standard Deviation of Age: 14.82
# ```

# %% [markdown]
# ### Insights:
# - The population has 891 passengers with a mean age of ~29.7 years and a standard deviation of ~14.52 years.
# - A 20% sample (178 passengers) has a mean age of ~30.17 years and a standard deviation of ~14.82 years.
# - This demonstrates how a sample can closely represent the population, but slight variations are expected due to sampling randomness.
#
# Let me know if you'd like further clarification or to explore another concept!

# %%
population
891
mean = 29.3
sd = 14.
population 
parameters 



sample 
178
mean = 30.33
sd = 14.25
sample statistics 
(statistics)


we are studying sample stat and trying to make inference on parameter

# %% [markdown]
# ### **Parameters and Sample Statistics**
#
# ---
#
# #### **1. What is a Parameter?**
# A **parameter** is a numerical value that describes a characteristic of a **population**. Since the population includes every member of the group, parameters are often difficult or impossible to measure directly. They are fixed values but unknown in most real-world cases.
#
# **Examples of Parameters**:
# - The average age of all people in a country (population mean).
# - The percentage of defective products in all items produced by a factory.
#
# ---
#
# #### **2. What is a Sample Statistic?**
# A **sample statistic** is a numerical value that describes a characteristic of a **sample** (a subset of the population). Sample statistics are used as estimates of population parameters. Since they are based on samples, they can vary depending on the sample selected.
#
# **Examples of Sample Statistics**:
# - The average age of 100 people randomly selected from a country.
# - The percentage of defective products in a sample of 500 items.
#
# ---
#
# #### **Key Difference: Parameter vs Sample Statistic**
# | **Aspect**           | **Parameter**                                  | **Sample Statistic**                          |
# |-----------------------|-----------------------------------------------|-----------------------------------------------|
# | **Definition**        | Describes a characteristic of the population  | Describes a characteristic of a sample        |
# | **Value**             | Fixed but often unknown                       | Varies depending on the sample                |
# | **Examples**          | Population mean (\( \mu \)), population proportion (\( p \)) | Sample mean (\( \bar{x} \)), sample proportion (\( \hat{p} \)) |
# | **Purpose**           | Describes the entire population               | Used to estimate population parameters        |
#
# ---
#
# #### **Simple Example**
# Imagine we want to calculate the **average age** of passengers on the Titanic.
#
# - The **population parameter** is the actual average age of all passengers on the Titanic (denoted as \( \mu \)).
# - The **sample statistic** is the average age calculated from a sample of passengers (denoted as \( \bar{x} \)).
#
# ---

# %%
### Python Code Example Using Titanic Dataset

import pandas as pd


# Step 1: Calculate population parameter (mean age of entire population)
population_mean_age = titanic_df['age'].mean()  # Population parameter (mean)

# %%
# Step 2: Draw a random sample (20% of the population)
sample_size = int(len(titanic_df) * 0.2)
sample = titanic_df.sample(n=sample_size, random_state=42)

# %%
# Step 3: Calculate sample statistic (mean age of the sample)
sample_mean_age = sample['age'].mean()

# %%
# Display results
print("Population Parameter:")
print(f"Mean Age of Population: {population_mean_age:.2f}")

print("\nSample Statistic:")
print(f"Mean Age of Sample: {sample_mean_age:.2f}")
# Out:
# Population Parameter:
# Mean Age of Population: 29.70
#
# Sample Statistic:
# Mean Age of Sample: 30.69

# %% [markdown]
# ### Key Insights:
# 1. **Population Parameter** (\( $\mu \$)):
#    - Represents the true average age of all passengers.
#    - Calculated from the entire dataset.
#
# 2. **Sample Statistic** (\( $\bar{x} \$)):
#    - Represents the average age of a subset of passengers.
#    - Approximates the population parameter but may vary due to randomness.
#
# ---
#
# This demonstrates how **sample statistics** (e.g., sample mean) are used to estimate **population parameters** (e.g., population mean). Let me know if you need clarification or want to explore another concept!

# %%
titanic_df
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 0           0       3    male  22.0      1      0   7.2500        S   Third
# 1           1       1  female  38.0      1      0  71.2833        C   First
# 2           1       3  female  26.0      0      0   7.9250        S   Third
# 3           1       1  female  35.0      1      0  53.1000        S   First
# 4           0       3    male  35.0      0      0   8.0500        S   Third
# ..        ...     ...     ...   ...    ...    ...      ...      ...     ...
# 886         0       2    male  27.0      0      0  13.0000        S  Second
# 887         1       1  female  19.0      0      0  30.0000        S   First
# 888         0       3  female   NaN      1      2  23.4500        S   Third
# 889         1       1    male  26.0      0      0  30.0000        C   First
# 890         0       3    male  32.0      0      0   7.7500        Q   Third
#
#        who  adult_male deck  embark_town alive  alone
# ...

# %%
titanic_df["sex"].unique()
# Out:
# array(['male', 'female'], dtype=object)

# %%
titanic_df["pclass"].unique()
# Out:
# array([3, 1, 2], dtype=int64)

# %%
titanic_df["age"].unique()
# Out:
# array([22.  , 38.  , 26.  , 35.  ,   nan, 54.  ,  2.  , 27.  , 14.  ,
#         4.  , 58.  , 20.  , 39.  , 55.  , 31.  , 34.  , 15.  , 28.  ,
#         8.  , 19.  , 40.  , 66.  , 42.  , 21.  , 18.  ,  3.  ,  7.  ,
#        49.  , 29.  , 65.  , 28.5 ,  5.  , 11.  , 45.  , 17.  , 32.  ,
#        16.  , 25.  ,  0.83, 30.  , 33.  , 23.  , 24.  , 46.  , 59.  ,
#        71.  , 37.  , 47.  , 14.5 , 70.5 , 32.5 , 12.  ,  9.  , 36.5 ,
#        51.  , 55.5 , 40.5 , 44.  ,  1.  , 61.  , 56.  , 50.  , 36.  ,
#        45.5 , 20.5 , 62.  , 41.  , 52.  , 63.  , 23.5 ,  0.92, 43.  ,
#        60.  , 10.  , 64.  , 13.  , 48.  ,  0.75, 53.  , 57.  , 80.  ,
#        70.  , 24.5 ,  6.  ,  0.67, 30.5 ,  0.42, 34.5 , 74.  ])

# %%
titanic_df["sibsp"].unique()
# Out:
# array([1, 0, 3, 4, 2, 5, 8], dtype=int64)

# %%
titanic_df["embarked"].unique()
# Out:
# array(['S', 'C', 'Q', nan], dtype=object)

# %%
titanic_df["class"].unique()
# Out:
# ['Third', 'First', 'Second']
# Categories (3, object): ['First', 'Second', 'Third']

# %% [markdown]
# ---
#
# # **Types of Data**

# %% [markdown]
# #### **1. Types of Data Based on Nature**
#
# ##### **1.1. Qualitative Data (Categorical Data)**
# - Represents categories or groups.
# - Non-numerical in nature, though numbers can sometimes be used as labels.
# - **Examples**:
#   - Gender: Male, Female
#   - Eye Color: Blue, Green, Brown
#   - Shirt Sizes: Small, Medium, Large
#
# **Types of Qualitative Data**:
# - **Nominal Data**: Categories with no inherent order. (e.g., Eye color)
# - **Ordinal Data**: Categories with a meaningful order, but the intervals between them are not consistent. (e.g., Shirt sizes)
#
# ##### **1.2. Quantitative Data (Numerical Data)**
# - Represents measurable quantities.
# - Always numerical in nature.
# - **Examples**:
#   - Age: 25, 30, 35
#   - Salary: $50,000, $60,000, $70,000
#
# **Types of Quantitative Data**:
# - **Discrete Data**: Counts or whole numbers. (e.g., Number of students in a class)
# - **Continuous Data**: Measured values that can take any value within a range. (e.g., Height, Weight)
#
# ---
#
# ### **2. Types of Data Based on Measurement Levels**
#
# #### **2.1. Nominal Data**
# - Categories with no logical order.
# - Example: Blood groups (A, B, AB, O).
#
# #### **2.2. Ordinal Data**
# - Categories with a logical order, but intervals are not equal.
# - Example: Movie ratings (1 star, 2 stars, 3 stars).
#
# #### **2.3. Interval Data**
# - Numerical data with meaningful intervals, but no true zero.
# - Example: Temperature in Celsius or Fahrenheit.
#
# ---
#
# ### **Summary Table**
#
# | **Type of Data**   | **Nature**              | **Examples**                   |
# |---------------------|-------------------------|---------------------------------|
# | **Nominal**         | Categorical (Qualitative) | Gender, Blood type             |
# | **Ordinal**         | Categorical (Qualitative) | Satisfaction level (Low, High) |
# | **Discrete**        | Numerical (Quantitative) | Number of children, Test scores|
# | **Continuous**      | Numerical (Quantitative) | Height, Weight, Temperature    |
# | **Interval**        | Numerical (Quantitative) | Temperature in Celsius         |
#
# ---

# %% [markdown]
# # **Python Code Example Using Pandas**

# %%
import pandas as pd

# Create a sample dataset
data = {
    'Name': ['Alice', 'Bob', 'Charlie', 'David'],  # Nominal
    'Gender': ['Female', 'Male', 'Male', 'Female'],  # Nominal
    'Satisfaction Level': ['High', 'Medium', 'Low', 'High'],  # Ordinal
    'Height_cm': [160.5, 170.2, 175.3, 180.4],  # Continuous
    'Test Score': [85, 88, 78, 92],  # Discrete
    'Temperature_C': [36.5, 37.0, 36.8, 37.2]  # Interval
}

df = pd.DataFrame(data)

# Classify types of data
data_types = {
    'Name': 'Nominal',
    'Gender': 'Nominal',
    'Satisfaction Level': 'Ordinal',
    'Height_cm': 'Continuous',
    'Test Score': 'Discrete',
    'Temperature_C': 'Interval'
}

# %%
print("Dataset:")
print(df)
print("\nData Types Classification:")
for column, dtype in data_types.items():
    print(f"{column}: {dtype}")
# Out:
# Dataset:
#       Name  Gender Satisfaction Level  Height_cm  Test Score  Temperature_C
# 0    Alice  Female               High      160.5          85           36.5
# 1      Bob    Male             Medium      170.2          88           37.0
# 2  Charlie    Male                Low      175.3          78           36.8
# 3    David  Female               High      180.4          92           37.2
#
# Data Types Classification:
# Name: Nominal
# Gender: Nominal
# Satisfaction Level: Ordinal
# Height_cm: Continuous
# Test Score: Discrete
# Temperature_C: Interval

# %% [markdown]
# ### Key Takeaways:
# - Nominal and ordinal data represent **categories**.
# - Interval and continuous data represent **numerical measurements**, but interval data lacks a true zero.
# - The **Pandas library** is helpful for organizing and classifying these data types.
#
# Let me know if you'd like further clarification or examples!

# %%
20,25,30,25,35,33,36,22,20   28

# %% [markdown]
# # **Measures of Central Tendency**

# %% [markdown]
# ### **Measures of Central Tendency**
#
# **Measures of central tendency** describe the central or typical value of a dataset. They summarize data with a single representative value and are used to understand the distribution of data.
#
# ---
#
# ### **1. Types of Measures of Central Tendency**
#
# #### **1.1. Mean (Arithmetic Average)**
# The mean is the sum of all values divided by the total number of values. It is the most commonly used measure but can be affected by extreme values (outliers).
#
# **Formula**:
# $$\[
# \text{Mean} = \frac{\text{Sum of all values}}{\text{Total number of values}}
# \]$$
#
# **Example**: The scores [10, 20, 30] have a mean of:
# \$$[
# \text{Mean} = \frac{10 + 20 + 30}{3} = 20
# \]$$
#
# ---

# %%
titanic_df["age"].mean()
# Out:
# 29.69911764705882

# %%
(50+55+52+51+55+99+98)/7
# Out:
# 65.71428571428571

# %%
median

# %%
50+55+52+51+99

# %%
52

# %%
titanic_df["age"].mean()
# Out:
# 29.69911764705882

# %%
titanic_df["age"].median()
# Out:
# 28.0

# %%
titanic_df.describe()
# Out:
#          survived      pclass         age       sibsp       parch        fare
# count  891.000000  891.000000  714.000000  891.000000  891.000000  891.000000
# mean     0.383838    2.308642   29.699118    0.523008    0.381594   32.204208
# std      0.486592    0.836071   14.526497    1.102743    0.806057   49.693429
# min      0.000000    1.000000    0.420000    0.000000    0.000000    0.000000
# 25%      0.000000    2.000000   20.125000    0.000000    0.000000    7.910400
# 50%      0.000000    3.000000   28.000000    0.000000    0.000000   14.454200
# 75%      1.000000    3.000000   38.000000    1.000000    0.000000   31.000000
# max      1.000000    3.000000   80.000000    8.000000    6.000000  512.329200

# %% [markdown]
# #### **1.2. Median**
# The median is the middle value when the data is sorted in ascending or descending order. It is less affected by outliers and skewed data.
#
# - If the number of observations is **odd**, the median is the middle value.
# - If the number of observations is **even**, the median is the average of the two middle values.
#
# **Example**:
# - For [10, 20, 30], the median is 20.
# - For [10, 20, 30, 40], the median is \$ \frac{20+30}{2} = 25 \$).
#
# ---

# %% [markdown]
# #### **1.3. Mode**
# The mode is the most frequently occurring value in the dataset. A dataset can have one mode, multiple modes, or no mode.
#
# **Example**:
# - For [10, 20, 20, 30], the mode is 20.
# - For [10, 10, 20, 20, 30], the modes are 10 and 20 (bimodal).
#
# ---

# %% [markdown]
# ### **Comparison of the Measures**
#
# | **Measure**  | **Best Use Case**                              | **Limitations**                               |
# |--------------|------------------------------------------------|-----------------------------------------------|
# | **Mean**     | Ideal for symmetrical data.                    | Sensitive to outliers and skewed data.        |
# | **Median**   | Robust for skewed data or data with outliers.  | Ignores the magnitude of data values.         |
# | **Mode**     | Best for categorical data or to find frequency.| May not exist or may not be unique.           |
#
# ---

# %%
### **Python Code Example Using Pandas**


import pandas as pd

# Create a sample dataset
data = {'Scores': [50, 60, 70, 80, 90, 100, 100]}
df = pd.DataFrame(data)

# Calculate measures of central tendency
mean = df['Scores'].mean()  # Mean
median = df['Scores'].median()  # Median
mode = df['Scores'].mode()[0]  # Mode (selecting the first mode in case of multiple modes)

# %%
# Display the results
print("Dataset:")
print(df)
print("\nMeasures of Central Tendency:")
print(f"Mean: {mean}")
print(f"Median: {median}")
print(f"Mode: {mode}")
# Out:
# Dataset:
#    Scores
# 0      50
# 1      60
# 2      70
# 3      80
# 4      90
# 5     100
# 6     100
#
# Measures of Central Tendency:
# Mean: 78.57142857142857
# Median: 80.0
# Mode: 100

# %%
titanic_df.head()
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 0         0       3    male  22.0      1      0   7.2500        S  Third
# 1         1       1  female  38.0      1      0  71.2833        C  First
# 2         1       3  female  26.0      0      0   7.9250        S  Third
# 3         1       1  female  35.0      1      0  53.1000        S  First
# 4         0       3    male  35.0      0      0   8.0500        S  Third
#
#      who  adult_male deck  embark_town alive  alone
# 0    man        True  NaN  Southampton    no  False
# 1  woman       False    C    Cherbourg   yes  False
# 2  woman       False  NaN  Southampton   yes   True
# 3  woman       False    C  Southampton   yes  False
# 4    man        True  NaN  Southampton    no   True

# %%
titanic_df["age"].mean()
# Out:
# 29.69911764705882

# %%
titanic_df["age"].median()
# Out:
# 28.0

# %% [markdown]
# ### **Key Insights**
# 1. The **mean** is useful for understanding the overall average but is sensitive to outliers.
# 2. The **median** is robust against outliers and better for skewed distributions.
# 3. The **mode** is best suited for identifying the most frequent value, especially in categorical datasets.
#
# Let me know if you'd like further explanations or examples!

# %% [markdown]
# # **Outlier**

# %% [markdown]
# An **outlier** is a data point that is significantly different from the rest of the data. It lies far away from the central tendency of the dataset and can distort statistical analyses like the mean and standard deviation.
#
# ---
#
# ### **Why Are Outliers Important?**
# 1. **Impact on Analysis**:
#    - Outliers can skew the results of statistical calculations like mean and standard deviation.
# 2. **Significance**:
#    - An outlier may indicate variability in the data, measurement errors, or a unique case worth exploring.
#
# ---
#
# ### **Types of Outliers**
# 1. **Univariate Outliers**:
#    - Outliers identified by analyzing a single variable.
#    - Example: A height of 250 cm in a dataset where the average height is around 170 cm.
#
# 2. **Multivariate Outliers**:
#    - Outliers identified by analyzing multiple variables simultaneously.
#    - Example: A person with low income and very high expenditure.

# %% [markdown]
# ---
#
# ### **Methods to Detect Outliers**
#
# #### **1. Statistical Methods**
# - **Z-Score**:
#   - Measures how far a data point is from the mean in terms of standard deviations.
#   - A Z-score greater than 3 or less than -3 is often considered an outlier.
#
#   **Formula**:
#   $$\[
#   Z = \frac{(X - \mu)}{\sigma}
#   \]
#   Where:
#   - \( X \) = Data point
#   - \( \mu \) = Mean
#   - \( \sigma \) = Standard deviation$$
#
# - **Interquartile Range (IQR)**:
#   - Detects outliers based on the spread of the middle 50% of the data.
#   - Outliers lie below \$( Q1 - 1.5 \times \text{IQR} \) or above \( Q3 + 1.5 \times \text{IQR} \$).
#
#   **Formula**:
#   \$[
#   \text{IQR} = Q3 - Q1
#   \$]
#
# #### **2. Visualization Methods**
# - Box plots
# - Scatter plots
#
# ---

# %% [markdown]
# ### **Python Code Example Using Pandas**

# %%
import pandas as pd
import numpy as np

# Sample dataset
data = {'Scores': [50, 60, 70, 80, 90, 100, 200]}  # 200 is an outlier
df = pd.DataFrame(data)

# Method 1: Detect outliers using IQR
Q1 = df['Scores'].quantile(0.25)  # First quartile (25th percentile)
Q3 = df['Scores'].quantile(0.75)  # Third quartile (75th percentile)
IQR = Q3 - Q1  # Interquartile range

lower_bound = Q1 - 1.5 * IQR
upper_bound = Q3 + 1.5 * IQR

outliers_iqr = df[(df['Scores'] < lower_bound) | (df['Scores'] > upper_bound)]

# Method 2: Detect outliers using Z-score
mean = df['Scores'].mean()
std_dev = df['Scores'].std()

df['Z-Score'] = (df['Scores'] - mean) / std_dev
outliers_z = df[abs(df['Z-Score']) > 3]

# %%
# Display results
print("Dataset:")
print(df)

print("\nOutliers Detected Using IQR:")
print(outliers_iqr)

print("\nOutliers Detected Using Z-Score:")
print(outliers_z)
# Out:
# Dataset:
#    Scores   Z-Score
# 0      50 -0.853090
# 1      60 -0.654036
# 2      70 -0.454981
# 3      80 -0.255927
# 4      90 -0.056873
# 5     100  0.142182
# 6     200  2.132725
#
# Outliers Detected Using IQR:
#    Scores
# 6     200
#
# Outliers Detected Using Z-Score:
# Empty DataFrame
# Columns: [Scores, Z-Score]
# Index: []

# %% [markdown]
# ### **Key Insights**
# 1. **Outlier Detection**:
#    - The value 200 is identified as an outlier using both IQR and Z-score methods.
# 2. **IQR**:
#    - Focuses on the central 50% of the data.
# 3. **Z-Score**:
#    - Measures deviation from the mean, useful for normally distributed data.
#
# Let me know if you'd like to explore more about handling outliers or related topics!

# %%
tips
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# Load the tips dataset
tips = sns.load_dataset('tips')

# %%
# Box Plot to detect outliers
plt.figure(figsize=(8, 6))
sns.boxplot(x=tips['total_bill'])
plt.title("Box Plot for Total Bill")
plt.show()

# %%
# Scatter Plot to detect outliers
plt.figure(figsize=(8, 6))
sns.scatterplot(x=tips['total_bill'], y=tips['tip'])
plt.title("Scatter Plot of Total Bill vs Tip")
plt.xlabel("Total Bill")
plt.ylabel("Tip")
plt.show()

# %% [markdown]
# ### **Explanation of Visualizations**
#
# 1. **Box Plot**:
#    - The box plot highlights outliers as points outside the "whiskers."
#    - These outliers lie beyond \( Q1 - 1.5 \times \text{IQR} \) or \( Q3 + 1.5 \times \text{IQR} \).
#
# 2. **Scatter Plot**:
#    - The scatter plot shows the relationship between `total_bill` and `tip`.
#    - Unusually high or low points compared to the rest of the data are potential outliers.
#
# ---
#
# ### Insights from Visualizations
# 1. **Box Plot**:
#    - Outliers in `total_bill` can be easily identified by their isolated placement.
#
# 2. **Scatter Plot**:
#    - Outliers appear as points that deviate significantly from the general trend of the relationship.
#
# Run this code to visualize the outliers in the **Tips dataset**. Let me know if you’d like to analyze or handle the detected outliers!

# %% [markdown]
# # **Measures of Dispersion**

# %% [markdown]
# **Measures of dispersion** describe the spread or variability in a dataset. They provide insight into how much the data points deviate from the central tendency (mean, median, or mode).
#
# ---
#
# ### **Why Are Measures of Dispersion Important?**
# - They complement central tendency measures by showing how data is distributed.
# - They help identify consistency and variability in the data.
# - They are essential for understanding outliers and the overall data range.
#
# ---
#
# ### **Types of Measures of Dispersion**
#
# #### **1. Range**
# The difference between the maximum and minimum values in the dataset.
#
# **Formula**:
# \$[
# \text{Range} = \text{Maximum Value} - \text{Minimum Value}
# \$]
#
# **Example**: For [10, 20, 30, 40, 50], the range is:
# \$[
# \text{Range} = 50 - 10 = 40
# \$]
#
# ---
#
# #### **2. Interquartile Range (IQR)**
# The range of the middle 50% of the data, calculated as the difference between the 75th percentile (\( Q3 \)) and the 25th percentile (\( Q1 \)).
#
# **Formula**:
# \$[
# \text{IQR} = Q3 - Q1
# \$]
#
# **Example**: For [10, 20, 30, 40, 50], the quartiles are:
# - \$( Q1 = 20 \), \( Q3 = 40 \)
# \[
# \text{IQR} = 40 - 20 = 20
# \$]
#
# ---
#
# #### **3. Variance**
# The average of the squared differences between each data point and the mean. It measures how far data points spread out around the mean.
#
# **Formula**:
# \$[
# \text{Variance} (\sigma^2) = \frac{\sum (X - \mu)^2}{N}
# \$]
# Where:
# - \$( X \$) = Data point
# - \($ \mu \$) = Mean
# - \($ N \$) = Number of data points
#
# ---
#
# #### **4. Standard Deviation (SD)**
# The square root of variance. It indicates the average amount by which data points differ from the mean.
#
# **Formula**:
# \[$
# \text{SD} = \sqrt{\text{Variance}}
# \]$
#
# ---

# %%
10,20,30,40,50,60

MCT is finding center number
measuare of dispersion is to talk about how the data is spread
variance 

Standard deviation

# %%
import pandas as pd

# Sample dataset
data = {'Scores': [50, 60, 70, 80, 90, 100, 110]}
df = pd.DataFrame(data)

# %%
# Calculate measures of dispersion
range_value = df['Scores'].max() - df['Scores'].min()  # Range
q1 = df['Scores'].quantile(0.25)  # First quartile (Q1)
q3 = df['Scores'].quantile(0.75)  # Third quartile (Q3)
iqr = q3 - q1  # Interquartile Range
variance = df['Scores'].var()  # Variance
std_dev = df['Scores'].std()  # Standard Deviation

# %%
# Display results
print("Dataset:")
print(df)
print("\nMeasures of Dispersion:")
print(f"Range: {range_value}")
print(f"Interquartile Range (IQR): {iqr}")
print(f"Variance: {variance:.2f}")
print(f"Standard Deviation: {std_dev:.2f}")
# Out:
# Dataset:
#    Scores
# 0      50
# 1      60
# 2      70
# 3      80
# 4      90
# 5     100
# 6     110
#
# Measures of Dispersion:
# Range: 60
# Interquartile Range (IQR): 30.0
# Variance: 466.67
# Standard Deviation: 21.60

# %% [markdown]
# ### **Key Insights**
# 1. **Range**: Shows the spread of the entire dataset.
# 2. **IQR**: Focuses on the spread of the central 50% of the data.
# 3. **Variance and SD**: Provide a detailed view of the data's deviation from the mean, with SD being easier to interpret in the same units as the data.
#
# Let me know if you'd like further examples or visualizations for these measures!

# %%
import seaborn as sns

# %%
df = sns.load_dataset("titanic")
df.head(2)
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 0         0       3    male  22.0      1      0   7.2500        S  Third
# 1         1       1  female  38.0      1      0  71.2833        C  First
#
#      who  adult_male deck  embark_town alive  alone
# 0    man        True  NaN  Southampton    no  False
# 1  woman       False    C    Cherbourg   yes  False

# %%
df.describe()
# Out:
#          survived      pclass         age       sibsp       parch        fare
# count  891.000000  891.000000  714.000000  891.000000  891.000000  891.000000
# mean     0.383838    2.308642   29.699118    0.523008    0.381594   32.204208
# std      0.486592    0.836071   14.526497    1.102743    0.806057   49.693429
# min      0.000000    1.000000    0.420000    0.000000    0.000000    0.000000
# 25%      0.000000    2.000000   20.125000    0.000000    0.000000    7.910400
# 50%      0.000000    3.000000   28.000000    0.000000    0.000000   14.454200
# 75%      1.000000    3.000000   38.000000    1.000000    0.000000   31.000000
# max      1.000000    3.000000   80.000000    8.000000    6.000000  512.329200

# %% [markdown]
# # **Empirical Rule (68-95-99.7 Rule)**

# %% [markdown]
# The **Empirical Rule** is a statistical principle that applies to **normal distributions** (bell-shaped curves). It states:
#
# 1. **68%** of the data falls within **1 standard deviation** of the mean.
# 2. **95%** of the data falls within **2 standard deviations** of the mean.
# 3. **99.7%** of the data falls within **3 standard deviations** of the mean.
#
# This rule helps in understanding how data is distributed in a normal distribution.
#
# ---
#
# ### **Why Is the Empirical Rule Useful?**
# - It provides a quick estimate of the spread of data.
# - It helps identify **outliers** (data points beyond \( 3\sigma \)).
# - It simplifies interpreting standard deviation in real-world problems.
#
# ---
#
# ### **Simple Example**
#
# Imagine a class of students has scores on a test with:
# - **Mean (\( \mu \)) = 70**
# - **Standard Deviation (\( \sigma \)) = 10**
#
# #### **Empirical Rule Application**
# 1. **68% Rule (1 SD)**:
#    - \( \mu ± 1\sigma = 70 ± 10 \)
#    - Range: [60, 80]
#    - **68%** of students scored between 60 and 80.
#
# 2. **95% Rule (2 SDs)**:
#    - \( \mu ± 2\sigma = 70 ± 20 \)
#    - Range: [50, 90]
#    - **95%** of students scored between 50 and 90.
#
# 3. **99.7% Rule (3 SDs)**:
#    - \( \mu ± 3\sigma = 70 ± 30 \)
#    - Range: [40, 100]
#    - **99.7%** of students scored between 40 and 100.
#
# Any score outside this range (below 40 or above 100) is a potential **outlier**.
#
# ---

# %% [markdown]
# ### **Coefficient of Variation (CV)**
#
# The **Coefficient of Variation (CV)** is a measure of relative variability. It expresses the standard deviation as a percentage of the mean, making it useful for comparing the degree of variation across datasets with different units or scales.

# %% [markdown]
# ### **Formula**
#
# \$[
# \text{CV} = \left( \frac{\text{Standard Deviation}}{\text{Mean}} \right) \times 100
# \$]
#
# Where:
# - **Standard Deviation (SD)** measures the spread of the data.
# - **Mean** is the average value of the dataset.
#
# ---
#
# ### **Key Features**
# - The **CV** is unitless, allowing comparisons across datasets with different units or scales.
# - It is typically used when comparing variability between datasets or measuring consistency.
# - A **lower CV** indicates more stability or consistency, while a **higher CV** indicates more variability.
#
# ---
#
# ### **Example**
#
# Imagine two datasets representing the weights of apples and oranges:
# - **Apples**: Mean = 150g, SD = 10g
# - **Oranges**: Mean = 200g, SD = 20g
#
# **Coefficient of Variation**:
# - Apples: \($ \text{CV} = \frac{10}{150} \times 100 = 6.67\% \$)
# - Oranges: \($ \text{CV} = \frac{20}{200} \times 100 = 10\% \$)
#
# This shows that apples are more consistent in weight compared to oranges.

# %% [markdown]
# ---
#
# ### **Python Code Example Using Pandas**

# %%
import pandas as pd

# Create a sample dataset
data = {'Category': ['A', 'B', 'C'], 'Mean': [100, 200, 300], 'SD': [15, 30, 60]}
df = pd.DataFrame(data)

# Calculate Coefficient of Variation (CV)
df['CV (%)'] = (df['SD'] / df['Mean']) * 100

# Display results
print("Dataset with Coefficient of Variation:")
print(df)
# Out:
# Dataset with Coefficient of Variation:
#   Category  Mean  SD  CV (%)
# 0        A   100  15    15.0
# 1        B   200  30    15.0
# 2        C   300  60    20.0

# %% [markdown]
# ---
#
# ### **Output Example**
#
# ```
# Dataset with Coefficient of Variation:
#   Category  Mean  SD      CV (%)
# 0        A   100  15   15.000000
# 1        B   200  30   15.000000
# 2        C   300  60   20.000000
# ```

# %% [markdown]
# ---
#
# ### **Insights**
# 1. Categories A and B have the same CV (15%), indicating similar consistency in their data relative to their means.
# 2. Category C has a higher CV (20%), indicating more variability in its data.
#
# ---
#
# ### **Use Cases of CV**
# - **Finance**: To compare the risk (variability) of investments.
# - **Manufacturing**: To assess consistency in product quality.
# - **Healthcare**: To compare the variability in test results.

# %% [markdown]
# ### **What is a Z-Score?**
#
# A **Z-score** measures how many standard deviations a data point is from the mean of the dataset. It helps standardize data and compare values across different datasets with varying scales or units.
#
# ---
#
# ### **Z-Score Formula**
#
# \$[
# Z = \frac{(X - \mu)}{\sigma}
# \]$
#
# Where:
# - \($ Z $\): Z-score
# - \($ X $\): Data point
# - \($ \mu $\): Mean of the dataset
# - \( $\sigma $\): Standard deviation of the dataset
#
# ---
#
# ### **Why Is Z-Score Useful?**
# 1. Identifies how unusual a data point is compared to the rest of the dataset.
# 2. Helps detect outliers (e.g., Z-scores beyond ±3 are often considered outliers).
# 3. Allows comparisons across datasets by converting them to a standard scale.
#
# ---
#
# ### **Simple Example**
#
# Consider a dataset: **[10, 12, 14, 16, 18]**
#
# #### **Step-by-Step Calculation**
# 1. **Calculate the Mean (\( \mu \))**:
#    \[$
#    \mu = \frac{10 + 12 + 14 + 16 + 18}{5} = 14
#    \]$
#
# 2. **Calculate the Standard Deviation (\( \sigma \))**:
#    - \( $\sigma = \sqrt{\frac{\sum (X - \mu)^2}{N}} $\)
#    - Variance \($ = \frac{(10-14)^2 + (12-14)^2 + (14-14)^2 + (16-14)^2 + (18-14)^2}{5} = 8 $\)
#    - Standard deviation \($ \sigma = \sqrt{8} = 2.83$ \)
#
# 3. **Calculate Z-Scores**:
#    \[$
#    Z = \frac{X - \mu}{\sigma}
#    \]$
#    - For \($ X = 10 \): \( Z = \frac{10 - 14}{2.83} = -1.41 \)$
#    - For \($ X = 12 \): \( Z = \frac{12 - 14}{2.83} = -0.71 \)$
#    - For \($ X = 14 \): \( Z = \frac{14 - 14}{2.83} = 0 \)$
#    - For \($ X = 16 \): \( Z = \frac{16 - 14}{2.83} = 0.71 \)$
#    - For \($ X = 18 \): \( Z = \frac{18 - 14}{2.83} = 1.41 \)$
#
# ---
#
#
#
#
#
# ### **Key Insights**
# 1. **Z-Score Interpretation**:
#    - **Negative Z-Score**: Data point is below the mean.
#    - **Zero Z-Score**: Data point equals the mean.
#    - **Positive Z-Score**: Data point is above the mean.
#
# 2. **Practical Application**:
#    - A Z-score helps identify unusual values or outliers in a dataset.
#    - For example, Z-scores beyond ±3 are considered extreme in a normal distribution.

# %% [markdown]
# ### Understanding Z-Score with Simple Terms
#
# The **z-score** tells us how far a value is from the average in terms of the spread of the data. It helps standardize data, so we can compare values from different scales.
#
# The formula is:
#
# $
# z = \frac{\text{Value} - \text{Average}}{\text{Spread}}
# $
#
# Where:
# - **Value** is the data point you’re analyzing.
# - **Average** is the mean of the data.
# - **Spread** is the standard deviation, which measures how spread out the data is.
#
# ---
#
# ### Example: Two Columns with Different Scales
#
# We have a dataset with two columns: **Height (in cm)** and **Weight (in kg)**.
#
# | Height (cm) | Weight (kg) |
# |-------------|-------------|
# | 160         | 50          |
# | 170         | 60          |
# | 180         | 70          |
# | 190         | 80          |
# | 200         | 90          |
#
# #### Step 1: Find the Average and Spread for Each Column
# - For **Height**:
#   - Average = \(180\), Spread = \(15.81\)
# - For **Weight**:
#   - Average = \(70\), Spread = \(15.81\)
#
# #### Step 2: Calculate Z-Scores for Each Value
# For the first row:
# - **Height (z-score):**
#   $
#   z = \frac{\text{160} - \text{180}}{\text{15.81}} = -1.26
#   $
# - **Weight (z-score):**
#   $
#   z = \frac{\text{50} - \text{70}}{\text{15.81}} = -1.26
#   $
#
# Repeat this for all rows.
#
# ---
#
# #### Standardized Dataset (Z-Scores):
#
# | Height (z-score) | Weight (z-score) |
# |-------------------|-------------------|
# | -1.26            | -1.26            |
# | -0.63            | -0.63            |
# |  0.00            |  0.00            |
# |  0.63            |  0.63            |
# |  1.26            |  1.26            |
#
# ---
#
# ### Why Use Z-Scores?
#
# 1. **Interpretation**:
#    - A z-score of **0** means the value is exactly the average.
#    - Positive z-scores mean the value is above the average.
#    - Negative z-scores mean the value is below the average.
#
# 2. **Comparison Across Scales**:
#    By converting data into z-scores, we make it easier to compare values from columns with different units or ranges, like height (cm) and weight (kg).
#
# ---
#
# ### Python Code Example
#
# Here’s how you can calculate z-scores using Python and Pandas:
#
# ```python
# import pandas as pd
# from scipy.stats import zscore
#
# # Sample dataset
# data = {'Height': [160, 170, 180, 190, 200],
#         'Weight': [50, 60, 70, 80, 90]}
# df = pd.DataFrame(data)
#
# # Calculate z-scores
# df['Height_zscore'] = zscore(df['Height'])
# df['Weight_zscore'] = zscore(df['Weight'])
#
# print(df)
# ```
#
# ---
#
# #### Output:
# | Height | Weight | Height_zscore | Weight_zscore |
# |--------|--------|---------------|---------------|
# | 160    | 50     | -1.26         | -1.26         |
# | 170    | 60     | -0.63         | -0.63         |
# | 180    | 70     |  0.00         |  0.00         |
# | 190    | 80     |  0.63         |  0.63         |
# | 200    | 90     |  1.26         |  1.26         |
#
# This shows the z-scores for both columns, making them directly comparable.

# %%
import seaborn as sns
import pandas as pd
from scipy.stats import zscore

# Load the tips dataset
tips = sns.load_dataset('tips')

# Calculate Z-scores for the total_bill column
tips['Z-Score'] = zscore(tips['total_bill'])

# %%
# Sort the dataset by Z-scores
sorted_tips = tips[['total_bill', 'Z-Score']].sort_values(by='Z-Score', ascending=False)

# %%
# Display the top and bottom Z-scores to identify potential outliers
print("Top Z-Scores (Potential High Outliers):")
print(sorted_tips.head())
# Out:
# Top Z-Scores (Potential High Outliers):
#      total_bill   Z-Score
# 170       50.81  3.492068
# 212       48.33  3.212919
# 59        48.27  3.206166
# 156       48.17  3.194910
# 182       45.35  2.877490

# %%
print("\nBottom Z-Scores (Potential Low Outliers):")
print(sorted_tips.tail())
# Out:
# Bottom Z-Scores (Potential Low Outliers):
#      total_bill   Z-Score
# 149        7.51 -1.381780
# 111        7.25 -1.411046
# 172        7.25 -1.411046
# 92         5.75 -1.579886
# 67         3.07 -1.881547

# %%
df.head()
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 0         0       3    male  22.0      1      0   7.2500        S  Third
# 1         1       1  female  38.0      1      0  71.2833        C  First
# 2         1       3  female  26.0      0      0   7.9250        S  Third
# 3         1       1  female  35.0      1      0  53.1000        S  First
# 4         0       3    male  35.0      0      0   8.0500        S  Third
#
#      who  adult_male deck  embark_town alive  alone
# 0    man        True  NaN  Southampton    no  False
# 1  woman       False    C    Cherbourg   yes  False
# 2  woman       False  NaN  Southampton   yes   True
# 3  woman       False    C  Southampton   yes  False
# 4    man        True  NaN  Southampton    no   True

# %%
amazon 
rating
1 to 5  1,2,3,4,5

# %%
df.shape
# Out:
# (891, 15)

# %%
df.columns
# Out:
# Index(['survived', 'pclass', 'sex', 'age', 'sibsp', 'parch', 'fare',
#        'embarked', 'class', 'who', 'adult_male', 'deck', 'embark_town',
#        'alive', 'alone'],
#       dtype='object')

# %%
df["pclass"].value_counts()
# Out:
# pclass
# 3    491
# 1    216
# 2    184
# Name: count, dtype: int64

# %%
df["pclass"].unique()
# Out:
# array([3, 1, 2], dtype=int64)

# %% [markdown]
# ### **Different Types of Data**
#
# Data can be classified into distinct types based on their nature, characteristics, and measurement scales. Understanding data types is crucial for selecting appropriate statistical methods and visualization techniques.
#
# ---
#
# ### **1. Types of Data Based on Nature**
#
# #### **1.1. Qualitative Data (Categorical Data)**
# - Represents categories, labels, or groups.
# - Non-numerical but can sometimes be assigned numerical codes.
# - **Examples**: Gender (Male, Female), Marital Status (Single, Married).
#
# **Types of Qualitative Data**:
# 1. **Nominal Data**:
#    - Categories with no inherent order.
#    - Example: Blood Groups (A, B, AB, O).
#
# 2. **Ordinal Data**:
#    - Categories with a meaningful order, but the intervals between them are not uniform.
#    - Example: Education Level (High School, Bachelor’s, Master’s).
#
# ---
#
# #### **1.2. Quantitative Data (Numerical Data)**
# - Represents measurable quantities.
# - Always numerical in nature.
# - **Examples**: Age, Salary, Height.
#
# **Types of Quantitative Data**:
# 1. **Discrete Data**:
#    - Counts or whole numbers.
#    - Example: Number of students in a class.
#
# 2. **Continuous Data**:
#    - Measured values that can take any value within a range.
#    - Example: Temperature, Weight.
#
# ---
#
# ### **2. Types of Data Based on Measurement Levels**
#
# #### **2.1. Nominal Scale**
# - Represents data that can only be categorized.
# - No ordering or ranking.
# - **Example**: Eye Color (Blue, Green, Brown).
#
# #### **2.2. Ordinal Scale**
# - Represents data with a meaningful order but unequal intervals.
# - **Example**: Movie Ratings (1 star, 2 stars, 3 stars).
#
# #### **2.3. Interval Scale**
# - Numerical data with equal intervals between values but no true zero.
# - **Example**: Temperature in Celsius (0°C does not indicate the absence of temperature).
#
# #### **2.4. Ratio Scale**
# - Numerical data with equal intervals and a true zero, allowing for meaningful ratios.
# - **Example**: Height, Weight (e.g., 60 kg is twice as heavy as 30 kg).
#
# ---
#
# ### **Summary Table**
#
# | **Type of Data**   | **Nature**              | **Examples**                   |
# |---------------------|-------------------------|---------------------------------|
# | **Nominal**         | Categorical (Qualitative) | Gender, Blood Type             |
# | **Ordinal**         | Categorical (Qualitative) | Satisfaction Level (Low, High) |
# | **Discrete**        | Numerical (Quantitative) | Number of children, Test Scores|
# | **Continuous**      | Numerical (Quantitative) | Height, Weight, Temperature    |
# | **Interval**        | Numerical (Quantitative) | Temperature in Celsius         |
# | **Ratio**           | Numerical (Quantitative) | Income, Age, Distance          |
#
# ---
#
# ### **Examples of Each Type**
#
# #### **Categorical Data**:
# - **Nominal**: Eye color of students: Blue, Brown, Green.
# - **Ordinal**: Education levels: High School < Bachelor’s < Master’s.
#
# #### **Numerical Data**:
# - **Discrete**: Number of students in different classes: 30, 40, 35.
# - **Continuous**: Heights of students: 150.5 cm, 160.2 cm, 165.8 cm.
#
# #### **Measurement Scales**:
# - **Nominal**: Car brands: Toyota, Ford, Honda.
# - **Ordinal**: Rankings in a competition: 1st, 2nd, 3rd.
# - **Interval**: Temperature in Fahrenheit: 32°F, 50°F, 68°F.
# - **Ratio**: Salaries: $30,000, $50,000, $100,000.
#
# ---
#
# ### **Python Code to Explore Data Types**
#
# Using Python’s Pandas library to analyze and classify data types:
#
#
#
# ### **Key Insights**
# - Understanding the type of data helps in choosing appropriate statistical tools and visualizations.
# - For example:
#   - **Categorical data** can be visualized using bar charts or pie charts.
#   - **Numerical data** is better suited for histograms, box plots, and scatter plots.
#
# Let me know if you’d like further clarification or examples!

# %% [markdown]
# # **Univariate Analysis**

# %% [markdown]
# **Univariate analysis** is the simplest form of data analysis, focusing on analyzing a single variable (or feature) at a time. The goal is to understand the distribution, central tendency, and dispersion of the data for that variable.
#
# ---
#
# ### **Key Components of Univariate Analysis**
#
# 1. **Types of Variables**:
#    - **Numerical (Continuous/Discrete)**: Variables with numeric values (e.g., Age, Salary).
#    - **Categorical**: Variables with distinct categories (e.g., Gender, Marital Status).
#
# 2. **Analysis Methods**:
#    - **Numerical Variables**:
#      - Summary statistics: Mean, Median, Mode, Variance, Standard Deviation.
#      - Visualization: Histograms, Box Plots, KDE Plots.
#    - **Categorical Variables**:
#      - Frequency counts and proportions.
#      - Visualization: Bar Charts, Pie Charts.
#
# ---
#
# ### **Steps in Univariate Analysis**
#
# #### **1. For Numerical Variables**
# - Check summary statistics (mean, median, standard deviation).
# - Visualize the distribution using histograms or box plots.
# - Identify outliers or skewness.
#
# #### **2. For Categorical Variables**
# - Count the frequency of each category.
# - Visualize the proportions using bar charts or pie charts.
